# %% [markdown]
# # E7 — Overwrite test
#
# DLA on revision span: does the cue write toward C along w?

# %%
import sys
from pathlib import Path
sys.path.insert(0,'.')
from IPython.display import display, Image
import pandas as pd
from E7_overwrite_test import main, OUT_DIR
main()
# Out:
# `torch_dtype` is deprecated! Use `dtype` instead!
# device: cpu
# Loaded pretrained model gpt2 into HookedTransformer
# ops_12+15 cue
# ops_12+15 filler
# ops_8+7 cue
# ops_8+7 filler
# ops_11+12 cue
# ops_11+12 filler
# ops_9+6 cue
# ops_9+6 filler
# ops_13+14 cue
# ops_13+14 filler
# ops_4+5 cue
# ops_4+5 filler
# ops_16+10 cue
# ops_16+10 filler
# ops_3+8 cue
# ops_3+8 filler
#                                     0
# mean_sum_revision_cue       17.727710
# sem_sum_revision_cue        17.442150
# frac_revision_toward_C_cue   0.375000
# mean_unit_revision_cue      -0.000790
# mean_sum_revision_filler     9.280031
# mean_cue_minus_filler        8.447679
# sem_cue_minus_filler        40.012922
# mean_sum_W                   2.949536
# mean_sum_W_window            8.873440
# mean_sum_ops2               37.707163
# mean_final_score             2.707783
# verdict: {
#   "competing_push_toward_C": false,
#   "mean_sum_post_revision_cue": 17.72771003143862,
# ...

# %%
display(pd.read_csv(OUT_DIR/'summary.csv').T)
for p in ['revision_layer_profile.png','region_comparison.png','cue_vs_filler.png']:
    display(Image(filename=OUT_DIR/p))
# Out:
#                                     0
# mean_sum_revision_cue       17.727710
# sem_sum_revision_cue        17.442150
# frac_revision_toward_C_cue   0.375000
# mean_unit_revision_cue      -0.000790
# mean_sum_revision_filler     9.280031
# mean_cue_minus_filler        8.447679
# sem_cue_minus_filler        40.012922
# mean_sum_W                   2.949536
# mean_sum_W_window            8.873440
# mean_sum_ops2               37.707163
# mean_final_score             2.707783
