# %% [markdown]
# # E4b follow-up — readout vs causality at \(t^*\)
#
# Overlays tuned-lens W−C (when preference *appears*) with patch Δ (when `t*` state is *causally necessary*).

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path('.').resolve()))
from IPython.display import Image, display
import pandas as pd
from E4b_readout_vs_causality import main, OUT_DIR
main()
# Out:
# `torch_dtype` is deprecated! Use `dtype` instead!
# device: cpu
# Loaded pretrained model gpt2 into HookedTransformer
# item: ops_12+15
# item: ops_8+7
# item: ops_11+12
# item: ops_9+6
# item: ops_13+14
# item: ops_4+5
# item: ops_16+10
# item: ops_3+8
#      item  final_score  emergence_tuned  emergence_logit  causal_onset_layer  causal_peak_layer  patch_delta_L5  patch_delta_L9  tuned_L5  tuned_L9
# ops_12+15     4.194221                5                5                   6                 11       -0.627191       -7.633224  0.109594  3.489273
#   ops_8+7     2.444412                6                6                   7                 11       -0.470401       -4.712137 -0.358277  2.163116
# ops_11+12     1.868966                6                7                   7                 11       -0.308072       -4.421784 -0.611934  1.324054
# ...

# %%
display(pd.read_csv(OUT_DIR/'readout_vs_causality_per_item.csv'))
for p in ['readout_vs_causality_raw.png','readout_vs_causality_normalized.png','readout_vs_causality_spaghetti.png']:
    display(Image(filename=OUT_DIR/p))
# Out:
#         item  final_score  emergence_tuned  emergence_logit  \
# 0  ops_12+15     4.194221                5                5
# 1    ops_8+7     2.444412                6                6
# 2  ops_11+12     1.868966                6                7
# 3    ops_9+6     2.768471                6                6
# 4  ops_13+14     1.262815                6                6
# 5    ops_4+5     2.113895                1                2
# 6  ops_16+10     4.489054                1                1
# 7    ops_3+8     2.520422                0                0
#
#    causal_onset_layer  causal_peak_layer  patch_delta_L5  patch_delta_L9  \
# 0                   6                 11       -0.627191       -7.633224
# 1                   7                 11       -0.470401       -4.712137
# 2                   7                 11       -0.308072       -4.421784
# 3                   6                 11       -0.505707       -5.056257
# ...
